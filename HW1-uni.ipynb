# %% [markdown]
# # COMS 4995_002 Deep Learning Assignment 1
# Due on Monday, Oct 9, 11:59pm
#
# This assignment can be done in groups of at most 3 students. Everyone must submit on Courseworks individually.

# %% [markdown]
# Write down the UNIs of your group (if applicable)
#
# Member 1: Name, UNI
#
# Member 2: Name, UNI
#
# Member 3: Name, UNI

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc
import glob
import sys
# you shouldn't need to make any more imports

# %%
class NeuralNetwork(object):
    """
    Abstraction of neural network.
    Stores parameters, activations, cached values. 
    Provides necessary functions for training and prediction. 
    """
    def __init__(self, layer_dimensions, drop_prob=0.0, reg_lambda=0.0):
        """
        Initializes the weights and biases for each layer
        :param layer_dimensions: (list) number of nodes in each layer
        :param drop_prob: drop probability for dropout layers. Only required in part 2 of the assignment
        :param reg_lambda: regularization parameter. Only required in part 2 of the assignment
        """
        np.random.seed(1)
        
        self.parameters = {}
        self.num_layers = len(layer_dimensions)
        self.drop_prob = drop_prob
        self.reg_lambda = reg_lambda
        
        # init parameters
        self.parameters = self.intializeParameters(layer_dimensions)
        
    def intializeParameters(self, layer_dimensions):
        eps = 0.01
        parameters = {}
        
        for l in range(self.num_layers - 1):
            parameters["W" + str(l+1)] = np.random.randn(layer_dimensions[l+1], layer_dimensions[l]) * eps
            parameters["b" + str(l+1)] = np.zeros((layer_dimensions[l+1],1))
        
        return parameters
    
    def affineForward(self, A, W, b):
        """
        Forward pass for the affine layer.
        :param A: input matrix, shape (L, S), where L is the number of hidden units in the previous layer and S is
        the number of samples
        :returns: the affine product WA + b, along with the cache required for the backward pass
        """
        return np.dot(W,A) + b
        

    def activationForward(self, A, activation="relu"):
        """
        Common interface to access all activation functions.
        :param A: input to the activation function
        :param prob: activation funciton to apply to A. Just "relu" for this assignment.
        :returns: activation(A)
        """ 
        return self.relu(A)

    def relu(self, X):
        return np.maximum(0,X)
            
    #def dropout(self, A, prob):
        """
        :param A: 
        :param prob: drop prob
        :returns: tuple (A, M) 
            WHERE
            A is matrix after applying dropout
            M is dropout mask, used in the backward pass
        """
        #return A, M

    def forwardPropagation(self, X):
        """
        Runs an input X through the neural network to compute activations
        for all layers. Returns the output computed at the last layer along
        with the cache required for backpropagation.
        :returns: (tuple) AL, cache
            WHERE 
            AL is activation of last layer
            cache is cached values for each layer that
                     are needed in further steps
        """
        #cache_A = []
        #cache_W = []
        #cache_Z = []
        cache = {}
        cache["A" + str(0)] = X
        
        for l in range(self.num_layers - 2):
            #print(l)
            A_prev = cache['A' + str(l)]
            Z = self.affineForward(A_prev, self.parameters["W" + str(l+1)], self.parameters["b" + str(l+1)])
            A = self.relu(Z)
            #print(cache.keys())
            cache["A" + str(l+1)] = A
            cache["Z" + str(l+1)] = Z
            
        Z = self.affineForward(A, self.parameters["W" + str(self.num_layers - 1)], self.parameters["b" + str(self.num_layers - 1)])
        cache["Z" + str(self.num_layers - 1)] = Z
        AL = self.softmax(Z)
        #return AL, cache_A, cache_W, cache_Z
        return AL, cache
    
    def softmax(self, Z):
        score = np.exp(Z - np.max(Z, axis=0))
        score /= np.sum(score, axis=0)
        return score
        #print(score.sum(axis=0))
        
        
    def costFunction(self, AL, y):
        """
        :param AL: Activation of last layer, shape (num_classes, S)
        :param y: labels, shape (S)
        :param alpha: regularization parameter
        :returns cost, dAL: A scalar denoting cost and the gradient of cost
        """
        # compute loss
        #print("hello")
        #print(y.shape)
        #print(len(y))
        #print(AL.shape)
        #cost = np.sum(-np.log(AL[y,range(len(y))])) / len(y)
        
        # gradient of cost 
        #dAL = AL
        #dAL[y,range(len(y))] -= 1
        #dAL[y,range(len(y))] /= len(y)
        
        #if self.reg_lambda > 0:
            # add regularization
            #pass
#         dAL = np.zeros((AL.shape[0], AL.shape[1]))
        y_one_hot = np.zeros((AL.shape[0], AL.shape[1]))
        
        cost = 0
        for i in range(len(y)):
            cost += -np.log(AL[y[i], i]) / len(y)
            y_one_hot[y[i], i] = 1
        
#         cost /= len(y)
        #if self.reg_lambda > 0:
        #pass
        
        dAL = (AL - y_one_hot) / len(y)
        
        return cost, dAL

    

    def affineBackward(self, dA_prev, cache, layer_num):
        """
        Backward pass for the affine layer.
        :param dA_prev: gradient from the next layer.
        :param cache: cache returned in affineForward
        :returns dA: gradient on the input to this layer
                 dW: gradient on the weights
                 db: gradient on the bias
        """
        dZ = self.activationBackward(dA_prev, cache, layer_num)
        
        W = self.parameters['W' + str(layer_num)]
        dA = np.dot(W.T, dZ)
        
        A = cache['A' + str(layer_num-1)]
        dw = np.dot(dZ, A.T)
        db = np.sum(dZ, axis = 1, keepdims = True)
        
        return dA, dw, db

    def activationBackward(self, dA, cache,  layer_num, activation="relu"):
        """
        Interface to call backward on activation functions.
        In this case, it's just relu. 
        """
        dZ = dA * self.relu_derivative(cache['Z' + str(layer_num)])
        return dZ
        
    def relu_derivative(self, cached_x):
        dx = 1.0 * (cached_x > 0)
        return dx

    def dropout_backward(self, dA, cache):
        return dA

    def backPropagation(self, dAL, Y, cache):
        """
        Run backpropagation to compute gradients on all paramters in the model
        :param dAL: gradient on the last layer of the network. Returned by the cost function.
        :param Y: labels
        :param cache: cached values during forwardprop
        :returns gradients: dW and db for each weight/bias
        """
        gradients = {}
        
        dZ = dAL  #dZ for the last layer is equal to the gradient of the softmax
        
        W = self.parameters['W' + str(self.num_layers - 1)]
        dA = np.dot(W.T, dZ)
        
        A = cache['A' + str(self.num_layers - 2)]
        dW = np.dot(dZ, A.T)
        db = np.sum(dZ, axis = 1, keepdims = True)
        
        gradients['dw' + str(self.num_layers - 1)] = dW
        gradients['db' + str(self.num_layers - 1)] = db
        
        for l in range(self.num_layers - 2, 0, -1):
            dA, dW, db = self.affineBackward(dA, cache, layer_num)
            gradients['dw' + str(l)] = dW
            gradients['db' + str(l)] = db
            

        #if self.drop_prob > 0:
            #call dropout_backward
          
            
        #if self.reg_lambda > 0:
            # add gradients from L2 regularization to each dW
        
        #print(gradients.keys())
        return gradients


    def updateParameters(self, gradients, alpha):
        """
        :param gradients: gradients for each weight/bias
        :param alpha: step size for gradient descent 
        """
        
        for l in range(self.num_layers-1):
            self.parameters["W" + str(l+1)] = self.parameters["W" + str(l+1)] - alpha * gradients["dw" + str(l+1)]
            self.parameters["b" + str(l+1)] = self.parameters["b" + str(l+1)] - alpha * gradients["db" + str(l+1)]
        

    def train(self, X, y, X_val, y_val, iters=1000, alpha=0.0001, batch_size=100, print_every=100):
        """
        :param X: input samples, each column is a sample
        :param y: labels for input samples, y.shape[0] must equal X.shape[1]
        :param iters: number of training iterations
        :param alpha: step size for gradient descent
        :param batch_size: number of samples in a minibatch
        :param print_every: no. of iterations to print debug info after
        """
        
        for i in range(0, iters):
            
            # get minibatch
            A_batch, y_batch = self.get_batch(X, y, batch_size)
            
            # forward prop
            AL, cache = self.forwardPropagation(A_batch)

            # compute loss
            cost, dAL = self.costFunction(AL, y_batch)
            
            # compute gradients
            gradients = self.backPropagation(dAL, y, cache)
            
            # update weights and biases based on gradient
            self.updateParameters(gradients, alpha)

            if i % print_every == 0:
                # print cost, train and validation set accuracies
                
                train_y_predict = self.predict(A_batch)
                train_accuracy = np.sum((train_y_predict == y_batch) * 1) / len(y_batch)
        
                print('%d iteration, training cost : %f:'%(i, cost))
                print('%d iteration, training acc is %f:'%(i, train_accuracy))
                
                AL, c = self.forwardPropagation(X_val)
                val_cost, _ = self.costFunction(AL, y_val)
                val_y_predict = self.predict(X_val)
                val_accuracy = np.sum((val_y_predict == y_val) * 1) / len(y_val)
                
                print('%d iteration, val cost : %f:'%(i, val_cost))
                print('%d iteration, val acc : %f:'%(i, val_accuracy)) 
                
                
    def predict(self, X):
        """
        Make predictions for each sample
        """
        AL,c = self.forwardPropagation(X)
        prediction = np.argmax(AL, axis=0)
        return prediction

    def get_batch(self, X, y, batch_size):
        """
        check
        Return minibatch of samples and labels
        
        :param X, y: samples and corresponding labels
        :parma batch_size: minibatch size
        :returns: (tuple) X_batch, y_batch
        
        """
        start_index = np.random.randint(0, X.shape[1] - batch_size)
        X_batch = X[:, start_index:(start_index + batch_size)]
        y_batch = y[start_index:(start_index + batch_size)]

        return X_batch, y_batch

# %%
# Helper functions, DO NOT modify this

def get_img_array(path):
    """
    Given path of image, returns it's numpy array
    """
    return scipy.misc.imread(path)

def get_files(folder):
    """
    Given path to folder, returns list of files in it
    """
    filenames = [file for file in glob.glob(folder+'*/*')]
    filenames.sort()
    return filenames

def get_label(filepath, label2id):
    """
    Files are assumed to be labeled as: /path/to/file/999_frog.png
    Returns label for a filepath
    """
    tokens = filepath.split('/')
    label = tokens[-1].split('_')[1][:-4]
    if label in label2id:
        return label2id[label]
    else:
        sys.exit("Invalid label: " + label)

# %%
# Functions to load data, DO NOT change these

def get_labels(folder, label2id):
    """
    Returns vector of labels extracted from filenames of all files in folder
    :param folder: path to data folder
    :param label2id: mapping of text labels to numeric ids. (Eg: automobile -> 0)
    """
    files = get_files(folder)
    y = []
    for f in files:
        y.append(get_label(f,label2id))
    return np.array(y)

def one_hot(y, num_classes=10):
    """
    Converts each label index in y to vector with one_hot encoding
    """
    y_one_hot = np.zeros((y.shape[0], num_classes))
    y_one_hot[y] = 1
    return y_one_hot.T

def get_label_mapping(label_file):
    """
    Returns mappings of label to index and index to label
    The input file has list of labels, each on a separate line.
    """
    with open(label_file, 'r') as f:
        id2label = f.readlines()
        id2label = [l.strip() for l in id2label]
    label2id = {}
    count = 0
    for label in id2label:
        label2id[label] = count
        count += 1
    return id2label, label2id

def get_images(folder):
    """
    returns numpy array of all samples in folder
    each column is a sample resized to 30x30 and flattened
    """
    files = get_files(folder)
    images = []
    count = 0
    
    for f in files:
        count += 1
        if count % 10000 == 0:
            print("Loaded {}/{}".format(count,len(files)))
        img_arr = get_img_array(f)
        img_arr = img_arr.flatten() / 255.0
        images.append(img_arr)
    X = np.column_stack(images)

    return X

def get_train_data(data_root_path):
    """
    Return X and y
    """
    train_data_path = data_root_path + 'train'
    id2label, label2id = get_label_mapping(data_root_path+'labels.txt')
    print(label2id)
    X = get_images(train_data_path)
    y = get_labels(train_data_path, label2id)
    return X, y

def save_predictions(filename, y):
    """
    Dumps y into .npy file
    """
    np.save(filename, y)

# %%
# Load the data
from sklearn.cross_validation import train_test_split
data_root_path = '/mnt/c/Users/bk262/Desktop/DeepLearning/HW1-data/cifar10-hw1/'
X_train, y_train = get_train_data(data_root_path) # this may take a few minutes
#print(np.matrix(X_train).shape)
#print(np.matrix(y_train).shape)
x_train, x_val, pred_train, pred_val = train_test_split(np.transpose(X_train), np.transpose(y_train), test_size=0.1, random_state=42)
X_train, y_train = np.transpose(x_train), np.transpose(pred_train)
X_val, y_val = np.transpose(x_val), np.transpose(pred_val)
#print(np.matrix(X_train).shape)
#print(np.matrix(y_train).shape)
#print(np.matrix(X_val).shape)
#print(np.matrix(y_val).shape)
X_test = get_images(data_root_path + 'test')
print('Data loading done')
# Out:
# {'deer': 4, 'bird': 2, 'frog': 6, 'dog': 5, 'truck': 9, 'horse': 7, 'automobile': 1, 'ship': 8, 'airplane': 0, 'cat': 3}
# Loaded 10000/50000
# Loaded 20000/50000
# Loaded 30000/50000
# Loaded 40000/50000
# Loaded 50000/50000
# Loaded 10000/10000
# Data loading done

# %%
def softmax(Z):
    score = np.exp(Z - np.max(Z, axis=0))
    score /= np.sum(score, axis=0)
    print(score)
    print(score.sum(axis=0))

Z = np.arange(12).reshape(3,4)        
softmax(Z)
# Out:
# [[  3.29320439e-04   3.29320439e-04   3.29320439e-04   3.29320439e-04]
#  [  1.79802867e-02   1.79802867e-02   1.79802867e-02   1.79802867e-02]
#  [  9.81690393e-01   9.81690393e-01   9.81690393e-01   9.81690393e-01]]
# [ 1.  1.  1.  1.]

# %% [markdown]
# ## Part 1
#
# #### Simple fully-connected deep neural network

# %%
#print(X_train.shape[0])
#layer_dimensions = [X_train.shape[0], 128, 32, 10]  # including the input and output layers
#NN = NeuralNetwork(layer_dimensions)
NN.train(X_train, y_train, X_val, y_val, iters=30000, alpha=0.003, batch_size=128, print_every=100)
# Out:
# 0 iteration, training cost : 1.244908:
# 0 iteration, training acc is 0.539062:
# 0 iteration, val cost : 1.380914:
# 0 iteration, val acc : 0.516400:
# 100 iteration, training cost : 1.295691:
# 100 iteration, training acc is 0.570312:
# 100 iteration, val cost : 1.380815:
# 100 iteration, val acc : 0.512200:
# 200 iteration, training cost : 1.020526:
# 200 iteration, training acc is 0.632812:
# 200 iteration, val cost : 1.382156:
# 200 iteration, val acc : 0.517000:
# 300 iteration, training cost : 1.025069:
# 300 iteration, training acc is 0.664062:
# 300 iteration, val cost : 1.382376:
# 300 iteration, val acc : 0.515800:
# 400 iteration, training cost : 1.083851:
# 400 iteration, training acc is 0.679688:
# 400 iteration, val cost : 1.377816:
# 400 iteration, val acc : 0.514400:
# 500 iteration, training cost : 1.152719:
# 500 iteration, training acc is 0.570312:
# 500 iteration, val cost : 1.376301:
# 500 iteration, val acc : 0.512600:
# 600 iteration, training cost : 1.281372:
# 600 iteration, training acc is 0.578125:
# 600 iteration, val cost : 1.389141:
# 600 iteration, val acc : 0.509600:
# 700 iteration, training cost : 1.196625:
# 700 iteration, training acc is 0.617188:
# 700 iteration, val cost : 1.377430:
# 700 iteration, val acc : 0.518200:
# 800 iteration, training cost : 1.211996:
# 800 iteration, training acc is 0.562500:
# 800 iteration, val cost : 1.379984:
# 800 iteration, val acc : 0.512200:
# 900 iteration, training cost : 1.143011:
# 900 iteration, training acc is 0.640625:
# 900 iteration, val cost : 1.374575:
# 900 iteration, val acc : 0.512000:
# 1000 iteration, training cost : 1.154542:
# 1000 iteration, training acc is 0.593750:
# 1000 iteration, val cost : 1.376389:
# 1000 iteration, val acc : 0.516600:
# 1100 iteration, training cost : 1.169521:
# 1100 iteration, training acc is 0.593750:
# 1100 iteration, val cost : 1.382206:
# 1100 iteration, val acc : 0.518000:
# 1200 iteration, training cost : 1.097473:
# 1200 iteration, training acc is 0.656250:
# 1200 iteration, val cost : 1.381252:
# 1200 iteration, val acc : 0.508200:
# 1300 iteration, training cost : 1.168821:
# 1300 iteration, training acc is 0.609375:
# 1300 iteration, val cost : 1.382079:
# 1300 iteration, val acc : 0.517600:
# 1400 iteration, training cost : 1.116273:
# 1400 iteration, training acc is 0.593750:
# 1400 iteration, val cost : 1.376108:
# 1400 iteration, val acc : 0.515200:
# 1500 iteration, training cost : 1.126553:
# 1500 iteration, training acc is 0.601562:
# 1500 iteration, val cost : 1.368672:
# 1500 iteration, val acc : 0.521000:
# 1600 iteration, training cost : 1.164952:
# 1600 iteration, training acc is 0.578125:
# 1600 iteration, val cost : 1.384780:
# 1600 iteration, val acc : 0.513400:
# 1700 iteration, training cost : 1.152475:
# 1700 iteration, training acc is 0.609375:
# 1700 iteration, val cost : 1.377005:
# 1700 iteration, val acc : 0.516800:
# 1800 iteration, training cost : 1.189026:
# 1800 iteration, training acc is 0.617188:
# 1800 iteration, val cost : 1.383503:
# 1800 iteration, val acc : 0.513400:
# 1900 iteration, training cost : 1.154220:
# 1900 iteration, training acc is 0.617188:
# 1900 iteration, val cost : 1.376128:
# 1900 iteration, val acc : 0.520800:
# 2000 iteration, training cost : 1.203571:
# 2000 iteration, training acc is 0.601562:
# 2000 iteration, val cost : 1.381263:
# 2000 iteration, val acc : 0.510200:
# 2100 iteration, training cost : 1.350972:
# 2100 iteration, training acc is 0.562500:
# 2100 iteration, val cost : 1.372057:
# 2100 iteration, val acc : 0.516600:
# 2200 iteration, training cost : 1.207762:
# 2200 iteration, training acc is 0.601562:
# 2200 iteration, val cost : 1.386940:
# 2200 iteration, val acc : 0.513000:
# 2300 iteration, training cost : 1.197384:
# 2300 iteration, training acc is 0.617188:
# 2300 iteration, val cost : 1.384792:
# 2300 iteration, val acc : 0.516400:
# 2400 iteration, training cost : 1.185736:
# 2400 iteration, training acc is 0.617188:
# 2400 iteration, val cost : 1.383840:
# 2400 iteration, val acc : 0.513600:
# 2500 iteration, training cost : 1.100889:
# 2500 iteration, training acc is 0.609375:
# 2500 iteration, val cost : 1.380092:
# 2500 iteration, val acc : 0.514000:
# 2600 iteration, training cost : 1.086420:
# 2600 iteration, training acc is 0.617188:
# 2600 iteration, val cost : 1.374592:
# 2600 iteration, val acc : 0.515200:
# 2700 iteration, training cost : 1.165017:
# 2700 iteration, training acc is 0.609375:
# 2700 iteration, val cost : 1.381311:
# 2700 iteration, val acc : 0.515600:
# 2800 iteration, training cost : 1.194803:
# 2800 iteration, training acc is 0.601562:
# 2800 iteration, val cost : 1.380445:
# 2800 iteration, val acc : 0.520200:
# 2900 iteration, training cost : 1.216419:
# 2900 iteration, training acc is 0.562500:
# 2900 iteration, val cost : 1.387758:
# 2900 iteration, val acc : 0.512400:
# 3000 iteration, training cost : 1.266355:
# 3000 iteration, training acc is 0.562500:
# 3000 iteration, val cost : 1.378126:
# 3000 iteration, val acc : 0.510200:
# 3100 iteration, training cost : 1.180353:
# 3100 iteration, training acc is 0.593750:
# 3100 iteration, val cost : 1.379998:
# 3100 iteration, val acc : 0.519600:
# 3200 iteration, training cost : 1.255370:
# 3200 iteration, training acc is 0.578125:
# 3200 iteration, val cost : 1.377316:
# 3200 iteration, val acc : 0.518400:
# 3300 iteration, training cost : 1.193077:
# 3300 iteration, training acc is 0.578125:
# 3300 iteration, val cost : 1.377091:
# 3300 iteration, val acc : 0.514600:
# 3400 iteration, training cost : 1.200146:
# 3400 iteration, training acc is 0.625000:
# 3400 iteration, val cost : 1.382582:
# 3400 iteration, val acc : 0.514600:
# 3500 iteration, training cost : 1.190302:
# 3500 iteration, training acc is 0.539062:
# 3500 iteration, val cost : 1.383349:
# 3500 iteration, val acc : 0.511400:
# 3600 iteration, training cost : 1.335738:
# 3600 iteration, training acc is 0.585938:
# 3600 iteration, val cost : 1.377427:
# 3600 iteration, val acc : 0.514200:
# 3700 iteration, training cost : 1.246744:
# 3700 iteration, training acc is 0.562500:
# 3700 iteration, val cost : 1.385211:
# 3700 iteration, val acc : 0.514200:
# 3800 iteration, training cost : 1.062619:
# 3800 iteration, training acc is 0.648438:
# 3800 iteration, val cost : 1.380156:
# 3800 iteration, val acc : 0.513400:
# 3900 iteration, training cost : 1.472480:
# 3900 iteration, training acc is 0.531250:
# 3900 iteration, val cost : 1.379270:
# 3900 iteration, val acc : 0.512000:
# 4000 iteration, training cost : 1.147236:
# 4000 iteration, training acc is 0.625000:
# 4000 iteration, val cost : 1.377858:
# 4000 iteration, val acc : 0.514600:
# 4100 iteration, training cost : 1.063989:
# 4100 iteration, training acc is 0.679688:
# 4100 iteration, val cost : 1.390515:
# 4100 iteration, val acc : 0.517400:
# 4200 iteration, training cost : 1.174378:
# 4200 iteration, training acc is 0.640625:
# 4200 iteration, val cost : 1.371567:
# 4200 iteration, val acc : 0.518800:
# 4300 iteration, training cost : 1.174090:
# 4300 iteration, training acc is 0.578125:
# 4300 iteration, val cost : 1.369159:
# 4300 iteration, val acc : 0.519000:
# 4400 iteration, training cost : 1.165919:
# 4400 iteration, training acc is 0.648438:
# 4400 iteration, val cost : 1.389616:
# 4400 iteration, val acc : 0.510200:
# 4500 iteration, training cost : 1.273040:
# 4500 iteration, training acc is 0.585938:
# 4500 iteration, val cost : 1.372860:
# 4500 iteration, val acc : 0.517600:
# 4600 iteration, training cost : 1.183522:
# 4600 iteration, training acc is 0.640625:
# 4600 iteration, val cost : 1.377897:
# 4600 iteration, val acc : 0.517400:
# 4700 iteration, training cost : 1.187835:
# 4700 iteration, training acc is 0.593750:
# 4700 iteration, val cost : 1.381371:
# 4700 iteration, val acc : 0.518600:
# 4800 iteration, training cost : 1.051915:
# 4800 iteration, training acc is 0.664062:
# 4800 iteration, val cost : 1.373017:
# 4800 iteration, val acc : 0.517800:
# 4900 iteration, training cost : 1.172749:
# 4900 iteration, training acc is 0.632812:
# 4900 iteration, val cost : 1.367628:
# 4900 iteration, val acc : 0.521000:
# 5000 iteration, training cost : 1.337339:
# 5000 iteration, training acc is 0.585938:
# 5000 iteration, val cost : 1.388762:
# 5000 iteration, val acc : 0.518400:
# 5100 iteration, training cost : 1.094703:
# 5100 iteration, training acc is 0.593750:
# 5100 iteration, val cost : 1.378860:
# 5100 iteration, val acc : 0.517600:
# 5200 iteration, training cost : 1.118240:
# 5200 iteration, training acc is 0.640625:
# 5200 iteration, val cost : 1.375736:
# 5200 iteration, val acc : 0.511600:
# 5300 iteration, training cost : 1.166496:
# 5300 iteration, training acc is 0.570312:
# 5300 iteration, val cost : 1.372542:
# 5300 iteration, val acc : 0.513800:
# 5400 iteration, training cost : 1.193468:
# 5400 iteration, training acc is 0.593750:
# 5400 iteration, val cost : 1.386205:
# 5400 iteration, val acc : 0.519000:
# 5500 iteration, training cost : 1.225778:
# 5500 iteration, training acc is 0.593750:
# 5500 iteration, val cost : 1.368483:
# 5500 iteration, val acc : 0.521800:
# 5600 iteration, training cost : 1.085280:
# 5600 iteration, training acc is 0.648438:
# 5600 iteration, val cost : 1.378373:
# 5600 iteration, val acc : 0.519200:
# 5700 iteration, training cost : 1.078539:
# 5700 iteration, training acc is 0.617188:
# 5700 iteration, val cost : 1.372638:
# 5700 iteration, val acc : 0.514600:
# 5800 iteration, training cost : 1.338782:
# 5800 iteration, training acc is 0.546875:
# 5800 iteration, val cost : 1.381360:
# 5800 iteration, val acc : 0.520800:
# 5900 iteration, training cost : 1.111380:
# 5900 iteration, training acc is 0.625000:
# 5900 iteration, val cost : 1.372738:
# 5900 iteration, val acc : 0.520000:
# 6000 iteration, training cost : 1.116218:
# 6000 iteration, training acc is 0.609375:
# 6000 iteration, val cost : 1.380692:
# 6000 iteration, val acc : 0.516000:
# 6100 iteration, training cost : 1.148576:
# 6100 iteration, training acc is 0.562500:
# 6100 iteration, val cost : 1.377921:
# 6100 iteration, val acc : 0.519400:
# 6200 iteration, training cost : 1.216453:
# 6200 iteration, training acc is 0.593750:
# 6200 iteration, val cost : 1.373885:
# 6200 iteration, val acc : 0.517600:
# 6300 iteration, training cost : 1.226211:
# 6300 iteration, training acc is 0.554688:
# 6300 iteration, val cost : 1.403000:
# 6300 iteration, val acc : 0.511800:
# 6400 iteration, training cost : 1.239832:
# 6400 iteration, training acc is 0.570312:
# 6400 iteration, val cost : 1.375819:
# 6400 iteration, val acc : 0.519800:
# 6500 iteration, training cost : 0.997460:
# 6500 iteration, training acc is 0.656250:
# 6500 iteration, val cost : 1.379709:
# 6500 iteration, val acc : 0.510800:
# 6600 iteration, training cost : 1.215120:
# 6600 iteration, training acc is 0.593750:
# 6600 iteration, val cost : 1.367576:
# 6600 iteration, val acc : 0.522600:
# 6700 iteration, training cost : 1.048844:
# 6700 iteration, training acc is 0.640625:
# 6700 iteration, val cost : 1.371304:
# 6700 iteration, val acc : 0.519000:
# 6800 iteration, training cost : 1.222746:
# 6800 iteration, training acc is 0.609375:
# 6800 iteration, val cost : 1.390785:
# 6800 iteration, val acc : 0.509000:
# 6900 iteration, training cost : 1.210055:
# 6900 iteration, training acc is 0.578125:
# 6900 iteration, val cost : 1.375933:
# 6900 iteration, val acc : 0.516400:
# 7000 iteration, training cost : 1.061402:
# 7000 iteration, training acc is 0.664062:
# 7000 iteration, val cost : 1.379756:
# 7000 iteration, val acc : 0.522000:
# 7100 iteration, training cost : 1.304918:
# 7100 iteration, training acc is 0.562500:
# 7100 iteration, val cost : 1.397004:
# 7100 iteration, val acc : 0.509600:
# 7200 iteration, training cost : 1.238678:
# 7200 iteration, training acc is 0.570312:
# 7200 iteration, val cost : 1.374910:
# 7200 iteration, val acc : 0.521200:
# 7300 iteration, training cost : 1.127162:
# 7300 iteration, training acc is 0.648438:
# 7300 iteration, val cost : 1.367292:
# 7300 iteration, val acc : 0.523800:
# 7400 iteration, training cost : 1.152698:
# 7400 iteration, training acc is 0.585938:
# 7400 iteration, val cost : 1.387871:
# 7400 iteration, val acc : 0.516000:
# 7500 iteration, training cost : 1.233111:
# 7500 iteration, training acc is 0.578125:
# 7500 iteration, val cost : 1.380327:
# 7500 iteration, val acc : 0.516400:
# 7600 iteration, training cost : 1.022592:
# 7600 iteration, training acc is 0.632812:
# 7600 iteration, val cost : 1.380430:
# 7600 iteration, val acc : 0.521200:
# 7700 iteration, training cost : 1.411269:
# 7700 iteration, training acc is 0.500000:
# 7700 iteration, val cost : 1.376768:
# 7700 iteration, val acc : 0.523000:
# 7800 iteration, training cost : 1.130193:
# 7800 iteration, training acc is 0.617188:
# 7800 iteration, val cost : 1.379158:
# 7800 iteration, val acc : 0.521200:
# 7900 iteration, training cost : 1.057904:
# 7900 iteration, training acc is 0.617188:
# 7900 iteration, val cost : 1.383568:
# 7900 iteration, val acc : 0.516400:
# 8000 iteration, training cost : 0.998491:
# 8000 iteration, training acc is 0.656250:
# 8000 iteration, val cost : 1.372887:
# 8000 iteration, val acc : 0.519800:
# 8100 iteration, training cost : 1.242157:
# 8100 iteration, training acc is 0.617188:
# 8100 iteration, val cost : 1.382680:
# 8100 iteration, val acc : 0.511000:
# 8200 iteration, training cost : 1.124894:
# 8200 iteration, training acc is 0.656250:
# 8200 iteration, val cost : 1.365063:
# 8200 iteration, val acc : 0.528000:
# 8300 iteration, training cost : 1.327784:
# 8300 iteration, training acc is 0.554688:
# 8300 iteration, val cost : 1.368221:
# 8300 iteration, val acc : 0.516000:
# 8400 iteration, training cost : 1.090706:
# 8400 iteration, training acc is 0.632812:
# 8400 iteration, val cost : 1.377613:
# 8400 iteration, val acc : 0.522600:
# 8500 iteration, training cost : 1.238510:
# 8500 iteration, training acc is 0.539062:
# 8500 iteration, val cost : 1.375725:
# 8500 iteration, val acc : 0.519000:
# 8600 iteration, training cost : 1.268535:
# 8600 iteration, training acc is 0.546875:
# 8600 iteration, val cost : 1.371692:
# 8600 iteration, val acc : 0.520000:
# 8700 iteration, training cost : 1.096171:
# 8700 iteration, training acc is 0.640625:
# 8700 iteration, val cost : 1.366776:
# 8700 iteration, val acc : 0.522800:
# 8800 iteration, training cost : 1.136724:
# 8800 iteration, training acc is 0.585938:
# 8800 iteration, val cost : 1.367100:
# 8800 iteration, val acc : 0.522400:
# 8900 iteration, training cost : 1.045220:
# 8900 iteration, training acc is 0.617188:
# 8900 iteration, val cost : 1.380334:
# 8900 iteration, val acc : 0.510800:
# 9000 iteration, training cost : 1.261918:
# 9000 iteration, training acc is 0.585938:
# 9000 iteration, val cost : 1.374607:
# 9000 iteration, val acc : 0.520400:
# 9100 iteration, training cost : 1.170635:
# 9100 iteration, training acc is 0.617188:
# 9100 iteration, val cost : 1.381318:
# 9100 iteration, val acc : 0.514200:
# 9200 iteration, training cost : 1.182379:
# 9200 iteration, training acc is 0.593750:
# 9200 iteration, val cost : 1.371282:
# 9200 iteration, val acc : 0.519600:
# 9300 iteration, training cost : 1.248098:
# 9300 iteration, training acc is 0.617188:
# 9300 iteration, val cost : 1.388914:
# 9300 iteration, val acc : 0.514400:
# 9400 iteration, training cost : 1.110127:
# 9400 iteration, training acc is 0.640625:
# 9400 iteration, val cost : 1.366914:
# 9400 iteration, val acc : 0.519800:
# 9500 iteration, training cost : 1.068610:
# 9500 iteration, training acc is 0.656250:
# 9500 iteration, val cost : 1.382276:
# 9500 iteration, val acc : 0.518800:
# 9600 iteration, training cost : 1.202716:
# 9600 iteration, training acc is 0.609375:
# 9600 iteration, val cost : 1.370295:
# 9600 iteration, val acc : 0.522000:
# 9700 iteration, training cost : 1.412660:
# 9700 iteration, training acc is 0.507812:
# 9700 iteration, val cost : 1.377705:
# 9700 iteration, val acc : 0.518800:
# 9800 iteration, training cost : 1.080254:
# 9800 iteration, training acc is 0.648438:
# 9800 iteration, val cost : 1.374731:
# 9800 iteration, val acc : 0.515400:
# 9900 iteration, training cost : 1.164858:
# 9900 iteration, training acc is 0.640625:
# 9900 iteration, val cost : 1.374537:
# 9900 iteration, val acc : 0.514400:
# 10000 iteration, training cost : 1.096407:
# 10000 iteration, training acc is 0.625000:
# 10000 iteration, val cost : 1.370123:
# 10000 iteration, val acc : 0.517800:
# 10100 iteration, training cost : 1.317944:
# 10100 iteration, training acc is 0.531250:
# 10100 iteration, val cost : 1.376248:
# 10100 iteration, val acc : 0.520400:
# 10200 iteration, training cost : 1.258392:
# 10200 iteration, training acc is 0.625000:
# 10200 iteration, val cost : 1.374172:
# 10200 iteration, val acc : 0.520200:
# 10300 iteration, training cost : 1.113377:
# 10300 iteration, training acc is 0.656250:
# 10300 iteration, val cost : 1.371033:
# 10300 iteration, val acc : 0.524000:
# 10400 iteration, training cost : 1.043371:
# 10400 iteration, training acc is 0.632812:
# 10400 iteration, val cost : 1.380327:
# 10400 iteration, val acc : 0.511800:
# 10500 iteration, training cost : 1.101157:
# 10500 iteration, training acc is 0.625000:
# 10500 iteration, val cost : 1.387089:
# 10500 iteration, val acc : 0.514600:
# 10600 iteration, training cost : 1.348184:
# 10600 iteration, training acc is 0.578125:
# 10600 iteration, val cost : 1.368770:
# 10600 iteration, val acc : 0.521000:
# 10700 iteration, training cost : 1.009282:
# 10700 iteration, training acc is 0.718750:
# 10700 iteration, val cost : 1.386657:
# 10700 iteration, val acc : 0.519000:
# 10800 iteration, training cost : 1.066134:
# 10800 iteration, training acc is 0.632812:
# 10800 iteration, val cost : 1.367935:
# 10800 iteration, val acc : 0.515800:
# 10900 iteration, training cost : 0.998688:
# 10900 iteration, training acc is 0.695312:
# 10900 iteration, val cost : 1.362958:
# 10900 iteration, val acc : 0.525800:
# 11000 iteration, training cost : 1.105943:
# 11000 iteration, training acc is 0.648438:
# 11000 iteration, val cost : 1.375413:
# 11000 iteration, val acc : 0.513600:
# 11100 iteration, training cost : 1.174431:
# 11100 iteration, training acc is 0.593750:
# 11100 iteration, val cost : 1.369358:
# 11100 iteration, val acc : 0.522800:
# 11200 iteration, training cost : 1.079709:
# 11200 iteration, training acc is 0.671875:
# 11200 iteration, val cost : 1.370807:
# 11200 iteration, val acc : 0.526200:
# 11300 iteration, training cost : 1.071200:
# 11300 iteration, training acc is 0.679688:
# 11300 iteration, val cost : 1.383449:
# 11300 iteration, val acc : 0.521800:
# 11400 iteration, training cost : 1.253286:
# 11400 iteration, training acc is 0.593750:
# 11400 iteration, val cost : 1.374760:
# 11400 iteration, val acc : 0.513800:
# 11500 iteration, training cost : 1.237237:
# 11500 iteration, training acc is 0.562500:
# 11500 iteration, val cost : 1.376669:
# 11500 iteration, val acc : 0.511600:
# 11600 iteration, training cost : 1.153965:
# 11600 iteration, training acc is 0.570312:
# 11600 iteration, val cost : 1.370683:
# 11600 iteration, val acc : 0.519600:
# 11700 iteration, training cost : 1.283123:
# 11700 iteration, training acc is 0.523438:
# 11700 iteration, val cost : 1.374383:
# 11700 iteration, val acc : 0.519600:
# 11800 iteration, training cost : 1.190743:
# 11800 iteration, training acc is 0.593750:
# 11800 iteration, val cost : 1.367051:
# 11800 iteration, val acc : 0.525600:
# 11900 iteration, training cost : 0.983012:
# 11900 iteration, training acc is 0.695312:
# 11900 iteration, val cost : 1.380548:
# 11900 iteration, val acc : 0.520400:
# 12000 iteration, training cost : 1.103386:
# 12000 iteration, training acc is 0.609375:
# 12000 iteration, val cost : 1.377305:
# 12000 iteration, val acc : 0.523600:
# 12100 iteration, training cost : 1.073526:
# 12100 iteration, training acc is 0.625000:
# 12100 iteration, val cost : 1.387572:
# 12100 iteration, val acc : 0.514000:
# 12200 iteration, training cost : 1.185121:
# 12200 iteration, training acc is 0.570312:
# 12200 iteration, val cost : 1.369081:
# 12200 iteration, val acc : 0.525000:
# 12300 iteration, training cost : 1.008426:
# 12300 iteration, training acc is 0.640625:
# 12300 iteration, val cost : 1.368652:
# 12300 iteration, val acc : 0.526400:
# 12400 iteration, training cost : 1.220382:
# 12400 iteration, training acc is 0.554688:
# 12400 iteration, val cost : 1.372160:
# 12400 iteration, val acc : 0.524800:
# 12500 iteration, training cost : 1.031180:
# 12500 iteration, training acc is 0.656250:
# 12500 iteration, val cost : 1.374050:
# 12500 iteration, val acc : 0.522000:
# 12600 iteration, training cost : 1.040371:
# 12600 iteration, training acc is 0.648438:
# 12600 iteration, val cost : 1.364124:
# 12600 iteration, val acc : 0.528200:
# 12700 iteration, training cost : 1.108534:
# 12700 iteration, training acc is 0.617188:
# 12700 iteration, val cost : 1.369344:
# 12700 iteration, val acc : 0.522800:
# 12800 iteration, training cost : 1.231699:
# 12800 iteration, training acc is 0.632812:
# 12800 iteration, val cost : 1.383907:
# 12800 iteration, val acc : 0.524200:
# 12900 iteration, training cost : 1.118963:
# 12900 iteration, training acc is 0.562500:
# 12900 iteration, val cost : 1.381760:
# 12900 iteration, val acc : 0.520200:
# 13000 iteration, training cost : 1.333621:
# 13000 iteration, training acc is 0.554688:
# 13000 iteration, val cost : 1.375008:
# 13000 iteration, val acc : 0.525600:
# 13100 iteration, training cost : 1.113009:
# 13100 iteration, training acc is 0.609375:
# 13100 iteration, val cost : 1.362054:
# 13100 iteration, val acc : 0.524400:
# 13200 iteration, training cost : 1.225946:
# 13200 iteration, training acc is 0.609375:
# 13200 iteration, val cost : 1.372473:
# 13200 iteration, val acc : 0.523400:
# 13300 iteration, training cost : 0.963996:
# 13300 iteration, training acc is 0.687500:
# 13300 iteration, val cost : 1.372143:
# 13300 iteration, val acc : 0.515800:
# 13400 iteration, training cost : 1.036848:
# 13400 iteration, training acc is 0.671875:
# 13400 iteration, val cost : 1.368783:
# 13400 iteration, val acc : 0.524800:
# 13500 iteration, training cost : 1.014508:
# 13500 iteration, training acc is 0.671875:
# 13500 iteration, val cost : 1.368335:
# 13500 iteration, val acc : 0.526400:
# 13600 iteration, training cost : 0.972677:
# 13600 iteration, training acc is 0.726562:
# 13600 iteration, val cost : 1.405282:
# 13600 iteration, val acc : 0.502800:
# 13700 iteration, training cost : 1.173818:
# 13700 iteration, training acc is 0.632812:
# 13700 iteration, val cost : 1.395740:
# 13700 iteration, val acc : 0.519000:
# 13800 iteration, training cost : 1.185544:
# 13800 iteration, training acc is 0.625000:
# 13800 iteration, val cost : 1.375170:
# 13800 iteration, val acc : 0.519000:
# 13900 iteration, training cost : 1.166311:
# 13900 iteration, training acc is 0.578125:
# 13900 iteration, val cost : 1.371228:
# 13900 iteration, val acc : 0.523400:
# 14000 iteration, training cost : 1.100493:
# 14000 iteration, training acc is 0.617188:
# 14000 iteration, val cost : 1.386692:
# 14000 iteration, val acc : 0.520600:
# 14100 iteration, training cost : 0.927984:
# 14100 iteration, training acc is 0.679688:
# 14100 iteration, val cost : 1.362172:
# 14100 iteration, val acc : 0.529000:
# 14200 iteration, training cost : 1.055626:
# 14200 iteration, training acc is 0.664062:
# 14200 iteration, val cost : 1.377192:
# 14200 iteration, val acc : 0.516800:
# 14300 iteration, training cost : 1.203672:
# 14300 iteration, training acc is 0.687500:
# 14300 iteration, val cost : 1.390912:
# 14300 iteration, val acc : 0.518600:
# 14400 iteration, training cost : 1.034584:
# 14400 iteration, training acc is 0.710938:
# 14400 iteration, val cost : 1.376817:
# 14400 iteration, val acc : 0.523800:
# 14500 iteration, training cost : 1.056591:
# 14500 iteration, training acc is 0.640625:
# 14500 iteration, val cost : 1.367462:
# 14500 iteration, val acc : 0.525200:
# 14600 iteration, training cost : 1.101973:
# 14600 iteration, training acc is 0.593750:
# 14600 iteration, val cost : 1.376049:
# 14600 iteration, val acc : 0.518400:
# 14700 iteration, training cost : 1.378467:
# 14700 iteration, training acc is 0.546875:
# 14700 iteration, val cost : 1.404445:
# 14700 iteration, val acc : 0.519600:
# 14800 iteration, training cost : 1.183990:
# 14800 iteration, training acc is 0.601562:
# 14800 iteration, val cost : 1.377453:
# 14800 iteration, val acc : 0.520800:
# 14900 iteration, training cost : 1.040549:
# 14900 iteration, training acc is 0.679688:
# 14900 iteration, val cost : 1.371265:
# 14900 iteration, val acc : 0.518600:
# 15000 iteration, training cost : 1.225564:
# 15000 iteration, training acc is 0.609375:
# 15000 iteration, val cost : 1.373503:
# 15000 iteration, val acc : 0.522600:
# 15100 iteration, training cost : 1.032887:
# 15100 iteration, training acc is 0.679688:
# 15100 iteration, val cost : 1.364909:
# 15100 iteration, val acc : 0.524800:
# 15200 iteration, training cost : 1.219836:
# 15200 iteration, training acc is 0.601562:
# 15200 iteration, val cost : 1.383728:
# 15200 iteration, val acc : 0.521600:
# 15300 iteration, training cost : 1.235948:
# 15300 iteration, training acc is 0.609375:
# 15300 iteration, val cost : 1.369479:
# 15300 iteration, val acc : 0.520400:
# 15400 iteration, training cost : 1.118999:
# 15400 iteration, training acc is 0.632812:
# 15400 iteration, val cost : 1.364163:
# 15400 iteration, val acc : 0.529000:
# 15500 iteration, training cost : 1.159839:
# 15500 iteration, training acc is 0.625000:
# 15500 iteration, val cost : 1.376602:
# 15500 iteration, val acc : 0.518600:
# 15600 iteration, training cost : 1.043503:
# 15600 iteration, training acc is 0.687500:
# 15600 iteration, val cost : 1.367697:
# 15600 iteration, val acc : 0.519200:
# 15700 iteration, training cost : 0.958683:
# 15700 iteration, training acc is 0.664062:
# 15700 iteration, val cost : 1.363782:
# 15700 iteration, val acc : 0.526200:
# 15800 iteration, training cost : 1.294184:
# 15800 iteration, training acc is 0.593750:
# 15800 iteration, val cost : 1.366078:
# 15800 iteration, val acc : 0.525800:
# 15900 iteration, training cost : 0.986358:
# 15900 iteration, training acc is 0.703125:
# 15900 iteration, val cost : 1.368919:
# 15900 iteration, val acc : 0.526600:
# 16000 iteration, training cost : 1.184048:
# 16000 iteration, training acc is 0.617188:
# 16000 iteration, val cost : 1.377626:
# 16000 iteration, val acc : 0.526200:
# 16100 iteration, training cost : 1.073356:
# 16100 iteration, training acc is 0.679688:
# 16100 iteration, val cost : 1.364632:
# 16100 iteration, val acc : 0.521800:
# 16200 iteration, training cost : 1.047051:
# 16200 iteration, training acc is 0.664062:
# 16200 iteration, val cost : 1.366034:
# 16200 iteration, val acc : 0.531400:
# 16300 iteration, training cost : 1.006218:
# 16300 iteration, training acc is 0.617188:
# 16300 iteration, val cost : 1.365887:
# 16300 iteration, val acc : 0.523200:
# 16400 iteration, training cost : 1.142003:
# 16400 iteration, training acc is 0.601562:
# 16400 iteration, val cost : 1.384165:
# 16400 iteration, val acc : 0.518800:
# 16500 iteration, training cost : 1.175706:
# 16500 iteration, training acc is 0.578125:
# 16500 iteration, val cost : 1.379751:
# 16500 iteration, val acc : 0.520600:
# 16600 iteration, training cost : 1.040293:
# 16600 iteration, training acc is 0.625000:
# 16600 iteration, val cost : 1.366191:
# 16600 iteration, val acc : 0.525200:
# 16700 iteration, training cost : 1.282701:
# 16700 iteration, training acc is 0.554688:
# 16700 iteration, val cost : 1.375900:
# 16700 iteration, val acc : 0.527600:
# 16800 iteration, training cost : 1.196387:
# 16800 iteration, training acc is 0.609375:
# 16800 iteration, val cost : 1.383702:
# 16800 iteration, val acc : 0.514600:
# 16900 iteration, training cost : 1.003653:
# 16900 iteration, training acc is 0.679688:
# 16900 iteration, val cost : 1.389530:
# 16900 iteration, val acc : 0.517600:
# 17000 iteration, training cost : 1.213308:
# 17000 iteration, training acc is 0.570312:
# 17000 iteration, val cost : 1.368504:
# 17000 iteration, val acc : 0.521400:
# 17100 iteration, training cost : 1.072333:
# 17100 iteration, training acc is 0.640625:
# 17100 iteration, val cost : 1.367527:
# 17100 iteration, val acc : 0.525800:
# 17200 iteration, training cost : 0.948486:
# 17200 iteration, training acc is 0.703125:
# 17200 iteration, val cost : 1.370342:
# 17200 iteration, val acc : 0.526200:
# 17300 iteration, training cost : 1.296758:
# 17300 iteration, training acc is 0.593750:
# 17300 iteration, val cost : 1.370988:
# 17300 iteration, val acc : 0.528200:
# 17400 iteration, training cost : 1.046565:
# 17400 iteration, training acc is 0.601562:
# 17400 iteration, val cost : 1.378609:
# 17400 iteration, val acc : 0.526000:
# 17500 iteration, training cost : 1.097776:
# 17500 iteration, training acc is 0.640625:
# 17500 iteration, val cost : 1.373602:
# 17500 iteration, val acc : 0.524800:
# 17600 iteration, training cost : 1.307754:
# 17600 iteration, training acc is 0.609375:
# 17600 iteration, val cost : 1.380951:
# 17600 iteration, val acc : 0.529400:
# 17700 iteration, training cost : 1.134857:
# 17700 iteration, training acc is 0.601562:
# 17700 iteration, val cost : 1.370165:
# 17700 iteration, val acc : 0.527600:
# 17800 iteration, training cost : 1.094526:
# 17800 iteration, training acc is 0.671875:
# 17800 iteration, val cost : 1.376758:
# 17800 iteration, val acc : 0.518400:
# 17900 iteration, training cost : 1.083228:
# 17900 iteration, training acc is 0.640625:
# 17900 iteration, val cost : 1.373923:
# 17900 iteration, val acc : 0.523000:
# 18000 iteration, training cost : 1.176762:
# 18000 iteration, training acc is 0.632812:
# 18000 iteration, val cost : 1.370157:
# 18000 iteration, val acc : 0.522000:
# 18100 iteration, training cost : 1.133808:
# 18100 iteration, training acc is 0.625000:
# 18100 iteration, val cost : 1.365313:
# 18100 iteration, val acc : 0.529600:
# 18200 iteration, training cost : 1.176665:
# 18200 iteration, training acc is 0.585938:
# 18200 iteration, val cost : 1.376195:
# 18200 iteration, val acc : 0.525400:
# 18300 iteration, training cost : 1.029397:
# 18300 iteration, training acc is 0.718750:
# 18300 iteration, val cost : 1.393491:
# 18300 iteration, val acc : 0.522000:
# 18400 iteration, training cost : 1.187123:
# 18400 iteration, training acc is 0.593750:
# 18400 iteration, val cost : 1.396464:
# 18400 iteration, val acc : 0.516000:
# 18500 iteration, training cost : 1.056005:
# 18500 iteration, training acc is 0.632812:
# 18500 iteration, val cost : 1.376488:
# 18500 iteration, val acc : 0.520200:
# 18600 iteration, training cost : 1.000867:
# 18600 iteration, training acc is 0.632812:
# 18600 iteration, val cost : 1.364462:
# 18600 iteration, val acc : 0.531000:
# 18700 iteration, training cost : 1.034749:
# 18700 iteration, training acc is 0.671875:
# 18700 iteration, val cost : 1.377986:
# 18700 iteration, val acc : 0.526600:
# 18800 iteration, training cost : 1.191601:
# 18800 iteration, training acc is 0.593750:
# 18800 iteration, val cost : 1.400928:
# 18800 iteration, val acc : 0.513000:
# 18900 iteration, training cost : 1.028752:
# 18900 iteration, training acc is 0.671875:
# 18900 iteration, val cost : 1.362637:
# 18900 iteration, val acc : 0.526200:
# 19000 iteration, training cost : 1.015486:
# 19000 iteration, training acc is 0.671875:
# 19000 iteration, val cost : 1.385477:
# 19000 iteration, val acc : 0.520800:
# 19100 iteration, training cost : 1.153862:
# 19100 iteration, training acc is 0.593750:
# 19100 iteration, val cost : 1.380955:
# 19100 iteration, val acc : 0.515000:
# 19200 iteration, training cost : 1.080732:
# 19200 iteration, training acc is 0.601562:
# 19200 iteration, val cost : 1.379777:
# 19200 iteration, val acc : 0.522800:
# 19300 iteration, training cost : 0.945867:
# 19300 iteration, training acc is 0.695312:
# 19300 iteration, val cost : 1.366262:
# 19300 iteration, val acc : 0.518200:
# 19400 iteration, training cost : 1.075115:
# 19400 iteration, training acc is 0.679688:
# 19400 iteration, val cost : 1.366943:
# 19400 iteration, val acc : 0.521800:
# 19500 iteration, training cost : 1.259618:
# 19500 iteration, training acc is 0.539062:
# 19500 iteration, val cost : 1.367427:
# 19500 iteration, val acc : 0.529200:
# 19600 iteration, training cost : 1.051886:
# 19600 iteration, training acc is 0.648438:
# 19600 iteration, val cost : 1.377694:
# 19600 iteration, val acc : 0.521400:
# 19700 iteration, training cost : 1.064846:
# 19700 iteration, training acc is 0.687500:
# 19700 iteration, val cost : 1.395117:
# 19700 iteration, val acc : 0.512600:
# 19800 iteration, training cost : 1.112712:
# 19800 iteration, training acc is 0.648438:
# 19800 iteration, val cost : 1.377187:
# 19800 iteration, val acc : 0.515400:
# 19900 iteration, training cost : 1.199139:
# 19900 iteration, training acc is 0.601562:
# 19900 iteration, val cost : 1.371180:
# 19900 iteration, val acc : 0.524600:
# 20000 iteration, training cost : 1.056306:
# 20000 iteration, training acc is 0.625000:
# 20000 iteration, val cost : 1.369598:
# 20000 iteration, val acc : 0.523800:
# 20100 iteration, training cost : 0.976480:
# 20100 iteration, training acc is 0.648438:
# 20100 iteration, val cost : 1.370588:
# 20100 iteration, val acc : 0.522800:
# 20200 iteration, training cost : 1.257294:
# 20200 iteration, training acc is 0.578125:
# 20200 iteration, val cost : 1.435034:
# 20200 iteration, val acc : 0.501000:
# 20300 iteration, training cost : 1.120535:
# 20300 iteration, training acc is 0.601562:
# 20300 iteration, val cost : 1.380189:
# 20300 iteration, val acc : 0.519000:
# 20400 iteration, training cost : 1.193365:
# 20400 iteration, training acc is 0.593750:
# 20400 iteration, val cost : 1.363322:
# 20400 iteration, val acc : 0.528400:
# 20500 iteration, training cost : 0.940021:
# 20500 iteration, training acc is 0.726562:
# 20500 iteration, val cost : 1.400397:
# 20500 iteration, val acc : 0.512400:
# 20600 iteration, training cost : 1.130111:
# 20600 iteration, training acc is 0.609375:
# 20600 iteration, val cost : 1.366783:
# 20600 iteration, val acc : 0.527400:
# 20700 iteration, training cost : 0.979650:
# 20700 iteration, training acc is 0.703125:
# 20700 iteration, val cost : 1.375099:
# 20700 iteration, val acc : 0.525000:
# 20800 iteration, training cost : 1.190856:
# 20800 iteration, training acc is 0.617188:
# 20800 iteration, val cost : 1.374000:
# 20800 iteration, val acc : 0.522800:
# 20900 iteration, training cost : 1.023131:
# 20900 iteration, training acc is 0.648438:
# 20900 iteration, val cost : 1.382206:
# 20900 iteration, val acc : 0.527000:
# 21000 iteration, training cost : 1.022853:
# 21000 iteration, training acc is 0.656250:
# 21000 iteration, val cost : 1.369787:
# 21000 iteration, val acc : 0.527200:
# 21100 iteration, training cost : 1.174143:
# 21100 iteration, training acc is 0.593750:
# 21100 iteration, val cost : 1.384642:
# 21100 iteration, val acc : 0.518800:
# 21200 iteration, training cost : 1.229270:
# 21200 iteration, training acc is 0.601562:
# 21200 iteration, val cost : 1.371709:
# 21200 iteration, val acc : 0.524800:
# 21300 iteration, training cost : 1.147223:
# 21300 iteration, training acc is 0.585938:
# 21300 iteration, val cost : 1.364511:
# 21300 iteration, val acc : 0.530600:
# 21400 iteration, training cost : 1.156938:
# 21400 iteration, training acc is 0.648438:
# 21400 iteration, val cost : 1.373576:
# 21400 iteration, val acc : 0.526400:
# 21500 iteration, training cost : 1.201537:
# 21500 iteration, training acc is 0.570312:
# 21500 iteration, val cost : 1.379090:
# 21500 iteration, val acc : 0.522800:
# 21600 iteration, training cost : 1.353929:
# 21600 iteration, training acc is 0.656250:
# 21600 iteration, val cost : 1.405613:
# 21600 iteration, val acc : 0.515400:
# 21700 iteration, training cost : 1.180392:
# 21700 iteration, training acc is 0.617188:
# 21700 iteration, val cost : 1.395940:
# 21700 iteration, val acc : 0.507000:
# 21800 iteration, training cost : 1.148598:
# 21800 iteration, training acc is 0.632812:
# 21800 iteration, val cost : 1.378185:
# 21800 iteration, val acc : 0.521800:
# 21900 iteration, training cost : 1.017979:
# 21900 iteration, training acc is 0.648438:
# 21900 iteration, val cost : 1.370629:
# 21900 iteration, val acc : 0.529000:
# 22000 iteration, training cost : 1.087377:
# 22000 iteration, training acc is 0.617188:
# 22000 iteration, val cost : 1.385822:
# 22000 iteration, val acc : 0.530000:
# 22100 iteration, training cost : 1.109764:
# 22100 iteration, training acc is 0.664062:
# 22100 iteration, val cost : 1.374910:
# 22100 iteration, val acc : 0.527000:
# 22200 iteration, training cost : 1.027598:
# 22200 iteration, training acc is 0.640625:
# 22200 iteration, val cost : 1.368053:
# 22200 iteration, val acc : 0.525000:
# 22300 iteration, training cost : 1.128014:
# 22300 iteration, training acc is 0.585938:
# 22300 iteration, val cost : 1.375477:
# 22300 iteration, val acc : 0.523400:
# 22400 iteration, training cost : 1.214872:
# 22400 iteration, training acc is 0.593750:
# 22400 iteration, val cost : 1.394805:
# 22400 iteration, val acc : 0.511200:
# 22500 iteration, training cost : 0.997265:
# 22500 iteration, training acc is 0.687500:
# 22500 iteration, val cost : 1.373485:
# 22500 iteration, val acc : 0.522000:
# 22600 iteration, training cost : 1.261242:
# 22600 iteration, training acc is 0.554688:
# 22600 iteration, val cost : 1.380250:
# 22600 iteration, val acc : 0.530400:
# 22700 iteration, training cost : 1.144585:
# 22700 iteration, training acc is 0.648438:
# 22700 iteration, val cost : 1.405694:
# 22700 iteration, val acc : 0.514000:
# 22800 iteration, training cost : 1.082140:
# 22800 iteration, training acc is 0.632812:
# 22800 iteration, val cost : 1.403152:
# 22800 iteration, val acc : 0.519400:
# 22900 iteration, training cost : 1.162873:
# 22900 iteration, training acc is 0.617188:
# 22900 iteration, val cost : 1.377345:
# 22900 iteration, val acc : 0.524800:
# 23000 iteration, training cost : 1.019746:
# 23000 iteration, training acc is 0.617188:
# 23000 iteration, val cost : 1.381784:
# 23000 iteration, val acc : 0.523600:
# 23100 iteration, training cost : 1.129297:
# 23100 iteration, training acc is 0.648438:
# 23100 iteration, val cost : 1.374474:
# 23100 iteration, val acc : 0.526800:
# 23200 iteration, training cost : 1.310193:
# 23200 iteration, training acc is 0.554688:
# 23200 iteration, val cost : 1.365109:
# 23200 iteration, val acc : 0.531400:
# 23300 iteration, training cost : 1.009198:
# 23300 iteration, training acc is 0.687500:
# 23300 iteration, val cost : 1.382342:
# 23300 iteration, val acc : 0.526200:
# 23400 iteration, training cost : 1.026348:
# 23400 iteration, training acc is 0.687500:
# 23400 iteration, val cost : 1.388048:
# 23400 iteration, val acc : 0.517400:
# 23500 iteration, training cost : 1.017845:
# 23500 iteration, training acc is 0.710938:
# 23500 iteration, val cost : 1.379411:
# 23500 iteration, val acc : 0.530400:
# 23600 iteration, training cost : 1.243077:
# 23600 iteration, training acc is 0.609375:
# 23600 iteration, val cost : 1.397366:
# 23600 iteration, val acc : 0.519600:
# 23700 iteration, training cost : 1.113146:
# 23700 iteration, training acc is 0.585938:
# 23700 iteration, val cost : 1.387285:
# 23700 iteration, val acc : 0.523800:
# 23800 iteration, training cost : 1.181237:
# 23800 iteration, training acc is 0.546875:
# 23800 iteration, val cost : 1.375436:
# 23800 iteration, val acc : 0.523200:
# 23900 iteration, training cost : 1.041568:
# 23900 iteration, training acc is 0.671875:
# 23900 iteration, val cost : 1.369659:
# 23900 iteration, val acc : 0.524400:
# 24000 iteration, training cost : 1.104354:
# 24000 iteration, training acc is 0.679688:
# 24000 iteration, val cost : 1.409981:
# 24000 iteration, val acc : 0.522800:
# 24100 iteration, training cost : 0.940832:
# 24100 iteration, training acc is 0.679688:
# 24100 iteration, val cost : 1.373159:
# 24100 iteration, val acc : 0.531000:
# 24200 iteration, training cost : 0.988509:
# 24200 iteration, training acc is 0.671875:
# 24200 iteration, val cost : 1.374092:
# 24200 iteration, val acc : 0.523200:
# 24300 iteration, training cost : 0.954608:
# 24300 iteration, training acc is 0.726562:
# 24300 iteration, val cost : 1.397910:
# 24300 iteration, val acc : 0.527400:
# 24400 iteration, training cost : 1.218684:
# 24400 iteration, training acc is 0.640625:
# 24400 iteration, val cost : 1.388233:
# 24400 iteration, val acc : 0.527800:
# 24500 iteration, training cost : 1.010590:
# 24500 iteration, training acc is 0.695312:
# 24500 iteration, val cost : 1.379983:
# 24500 iteration, val acc : 0.526800:
# 24600 iteration, training cost : 1.055088:
# 24600 iteration, training acc is 0.632812:
# 24600 iteration, val cost : 1.365487:
# 24600 iteration, val acc : 0.528800:
# 24700 iteration, training cost : 1.295699:
# 24700 iteration, training acc is 0.601562:
# 24700 iteration, val cost : 1.378948:
# 24700 iteration, val acc : 0.527600:
# 24800 iteration, training cost : 1.114229:
# 24800 iteration, training acc is 0.664062:
# 24800 iteration, val cost : 1.377626:
# 24800 iteration, val acc : 0.525000:
# 24900 iteration, training cost : 1.214733:
# 24900 iteration, training acc is 0.578125:
# 24900 iteration, val cost : 1.374162:
# 24900 iteration, val acc : 0.527400:
# 25000 iteration, training cost : 1.195909:
# 25000 iteration, training acc is 0.609375:
# 25000 iteration, val cost : 1.393019:
# 25000 iteration, val acc : 0.522000:
# 25100 iteration, training cost : 1.200839:
# 25100 iteration, training acc is 0.664062:
# 25100 iteration, val cost : 1.381851:
# 25100 iteration, val acc : 0.522200:
# 25200 iteration, training cost : 1.099180:
# 25200 iteration, training acc is 0.640625:
# 25200 iteration, val cost : 1.370268:
# 25200 iteration, val acc : 0.527200:
# 25300 iteration, training cost : 1.241827:
# 25300 iteration, training acc is 0.609375:
# 25300 iteration, val cost : 1.382245:
# 25300 iteration, val acc : 0.527200:
# 25400 iteration, training cost : 1.101105:
# 25400 iteration, training acc is 0.648438:
# 25400 iteration, val cost : 1.375391:
# 25400 iteration, val acc : 0.530600:
# 25500 iteration, training cost : 1.331804:
# 25500 iteration, training acc is 0.625000:
# 25500 iteration, val cost : 1.396167:
# 25500 iteration, val acc : 0.528800:
# 25600 iteration, training cost : 1.036750:
# 25600 iteration, training acc is 0.656250:
# 25600 iteration, val cost : 1.371973:
# 25600 iteration, val acc : 0.531400:
# 25700 iteration, training cost : 1.063029:
# 25700 iteration, training acc is 0.632812:
# 25700 iteration, val cost : 1.385844:
# 25700 iteration, val acc : 0.523400:
# 25800 iteration, training cost : 1.001106:
# 25800 iteration, training acc is 0.664062:
# 25800 iteration, val cost : 1.373049:
# 25800 iteration, val acc : 0.523200:
# 25900 iteration, training cost : 1.105542:
# 25900 iteration, training acc is 0.656250:
# 25900 iteration, val cost : 1.371364:
# 25900 iteration, val acc : 0.533000:
# 26000 iteration, training cost : 1.069995:
# 26000 iteration, training acc is 0.664062:
# 26000 iteration, val cost : 1.396374:
# 26000 iteration, val acc : 0.525000:
# 26100 iteration, training cost : 1.099837:
# 26100 iteration, training acc is 0.625000:
# 26100 iteration, val cost : 1.376543:
# 26100 iteration, val acc : 0.529600:
# 26200 iteration, training cost : 1.136438:
# 26200 iteration, training acc is 0.617188:
# 26200 iteration, val cost : 1.381151:
# 26200 iteration, val acc : 0.530800:
# 26300 iteration, training cost : 1.135822:
# 26300 iteration, training acc is 0.648438:
# 26300 iteration, val cost : 1.397630:
# 26300 iteration, val acc : 0.518400:
# 26400 iteration, training cost : 1.159916:
# 26400 iteration, training acc is 0.640625:
# 26400 iteration, val cost : 1.365972:
# 26400 iteration, val acc : 0.531800:
# 26500 iteration, training cost : 1.164715:
# 26500 iteration, training acc is 0.640625:
# 26500 iteration, val cost : 1.434815:
# 26500 iteration, val acc : 0.506200:
# 26600 iteration, training cost : 1.034323:
# 26600 iteration, training acc is 0.664062:
# 26600 iteration, val cost : 1.376539:
# 26600 iteration, val acc : 0.522800:
# 26700 iteration, training cost : 1.010903:
# 26700 iteration, training acc is 0.609375:
# 26700 iteration, val cost : 1.369419:
# 26700 iteration, val acc : 0.528400:
# 26800 iteration, training cost : 0.978542:
# 26800 iteration, training acc is 0.632812:
# 26800 iteration, val cost : 1.382701:
# 26800 iteration, val acc : 0.522000:
# 26900 iteration, training cost : 1.021129:
# 26900 iteration, training acc is 0.664062:
# 26900 iteration, val cost : 1.387725:
# 26900 iteration, val acc : 0.522000:
# 27000 iteration, training cost : 1.076367:
# 27000 iteration, training acc is 0.648438:
# 27000 iteration, val cost : 1.372420:
# 27000 iteration, val acc : 0.530400:
# 27100 iteration, training cost : 0.948861:
# 27100 iteration, training acc is 0.703125:
# 27100 iteration, val cost : 1.368545:
# 27100 iteration, val acc : 0.528400:
# 27200 iteration, training cost : 0.959971:
# 27200 iteration, training acc is 0.710938:
# 27200 iteration, val cost : 1.368745:
# 27200 iteration, val acc : 0.528400:
# 27300 iteration, training cost : 1.015764:
# 27300 iteration, training acc is 0.632812:
# 27300 iteration, val cost : 1.376244:
# 27300 iteration, val acc : 0.528400:
# 27400 iteration, training cost : 1.171216:
# 27400 iteration, training acc is 0.578125:
# 27400 iteration, val cost : 1.387301:
# 27400 iteration, val acc : 0.521800:
# 27500 iteration, training cost : 1.195646:
# 27500 iteration, training acc is 0.617188:
# 27500 iteration, val cost : 1.391759:
# 27500 iteration, val acc : 0.525000:
# 27600 iteration, training cost : 0.976698:
# 27600 iteration, training acc is 0.687500:
# 27600 iteration, val cost : 1.374218:
# 27600 iteration, val acc : 0.529600:
# 27700 iteration, training cost : 1.110102:
# 27700 iteration, training acc is 0.640625:
# 27700 iteration, val cost : 1.376882:
# 27700 iteration, val acc : 0.530000:
# 27800 iteration, training cost : 1.044866:
# 27800 iteration, training acc is 0.718750:
# 27800 iteration, val cost : 1.419073:
# 27800 iteration, val acc : 0.524600:
# 27900 iteration, training cost : 1.171718:
# 27900 iteration, training acc is 0.601562:
# 27900 iteration, val cost : 1.413910:
# 27900 iteration, val acc : 0.508200:
# 28000 iteration, training cost : 1.067141:
# 28000 iteration, training acc is 0.664062:
# 28000 iteration, val cost : 1.369692:
# 28000 iteration, val acc : 0.535400:
# 28100 iteration, training cost : 1.001042:
# 28100 iteration, training acc is 0.640625:
# 28100 iteration, val cost : 1.370052:
# 28100 iteration, val acc : 0.528400:
# 28200 iteration, training cost : 1.165363:
# 28200 iteration, training acc is 0.625000:
# 28200 iteration, val cost : 1.491089:
# 28200 iteration, val acc : 0.496200:
# 28300 iteration, training cost : 1.083780:
# 28300 iteration, training acc is 0.617188:
# 28300 iteration, val cost : 1.371241:
# 28300 iteration, val acc : 0.534000:
# 28400 iteration, training cost : 1.337402:
# 28400 iteration, training acc is 0.507812:
# 28400 iteration, val cost : 1.379463:
# 28400 iteration, val acc : 0.530200:
# 28500 iteration, training cost : 1.061631:
# 28500 iteration, training acc is 0.632812:
# 28500 iteration, val cost : 1.366850:
# 28500 iteration, val acc : 0.532600:
# 28600 iteration, training cost : 1.212784:
# 28600 iteration, training acc is 0.648438:
# 28600 iteration, val cost : 1.387850:
# 28600 iteration, val acc : 0.518600:
# 28700 iteration, training cost : 0.964555:
# 28700 iteration, training acc is 0.695312:
# 28700 iteration, val cost : 1.382120:
# 28700 iteration, val acc : 0.529400:
# 28800 iteration, training cost : 1.120744:
# 28800 iteration, training acc is 0.585938:
# 28800 iteration, val cost : 1.399925:
# 28800 iteration, val acc : 0.526200:
# 28900 iteration, training cost : 1.106436:
# 28900 iteration, training acc is 0.617188:
# 28900 iteration, val cost : 1.402686:
# 28900 iteration, val acc : 0.525800:
# 29000 iteration, training cost : 1.041270:
# 29000 iteration, training acc is 0.617188:
# 29000 iteration, val cost : 1.376004:
# 29000 iteration, val acc : 0.530000:
# 29100 iteration, training cost : 1.056255:
# 29100 iteration, training acc is 0.648438:
# 29100 iteration, val cost : 1.377663:
# 29100 iteration, val acc : 0.526200:
# 29200 iteration, training cost : 1.129384:
# 29200 iteration, training acc is 0.687500:
# 29200 iteration, val cost : 1.398577:
# 29200 iteration, val acc : 0.522600:
# 29300 iteration, training cost : 1.198333:
# 29300 iteration, training acc is 0.656250:
# 29300 iteration, val cost : 1.440850:
# 29300 iteration, val acc : 0.508800:
# 29400 iteration, training cost : 1.163984:
# 29400 iteration, training acc is 0.625000:
# 29400 iteration, val cost : 1.374263:
# 29400 iteration, val acc : 0.538400:
# 29500 iteration, training cost : 1.143345:
# 29500 iteration, training acc is 0.664062:
# 29500 iteration, val cost : 1.399521:
# 29500 iteration, val acc : 0.519800:
# 29600 iteration, training cost : 1.093418:
# 29600 iteration, training acc is 0.640625:
# 29600 iteration, val cost : 1.461210:
# 29600 iteration, val acc : 0.495000:
# 29700 iteration, training cost : 0.961919:
# 29700 iteration, training acc is 0.750000:
# 29700 iteration, val cost : 1.383140:
# 29700 iteration, val acc : 0.525600:
# 29800 iteration, training cost : 1.134454:
# 29800 iteration, training acc is 0.601562:
# 29800 iteration, val cost : 1.373484:
# 29800 iteration, val acc : 0.531800:
# 29900 iteration, training cost : 0.997040:
# 29900 iteration, training acc is 0.648438:
# 29900 iteration, val cost : 1.386556:
# 29900 iteration, val acc : 0.519600:

# %%
y_predicted = NN.predict(X_test)
save_predictions('ans1-uni', y_predicted)
# Out:
# (1000, 10000)
# (300, 10000)
# (30, 10000)

# %%
# test if your numpy file has been saved correctly
loaded_y = np.load('ans1-uni.npy')
print(loaded_y.shape)
loaded_y[:10]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-59-c78aac95c20c> in <module>()
#       1 # test if your numpy file has been saved correctly
# ----> 2 loaded_y = np.load('ans1-uni.npy')
#       3 print(loaded_y.shape)
#       4 loaded_y[:10]
#
# /root/anaconda3/lib/python3.5/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     360     own_fid = False
#     361     if isinstance(file, basestring):
# --> 362         fid = open(file, "rb")
#     363         own_fid = True
#     364     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ans1-uni.npy'

# %% [markdown]
# ## Part 2: Regularizing the neural network
# #### Add dropout and L2 regularization

# %%
NN2 = NeuralNetwork(layer_dimensions, drop_prob=0, reg_lambda=0)
NN2.train(X_train, y_train, iters=1000, alpha=0.00001, batch_size=1000, print_every=10)

# %%
y_predicted2 = NN2.predict(X)
save_predictions(y_predicted, 'ans2-uni')
